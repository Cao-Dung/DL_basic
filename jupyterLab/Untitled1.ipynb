# %%
import requests
import pdfplumber
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# Lớp OllamaLLM để kết nối với Ollama API
class OllamaLLM:
    def __init__(self, model="gpt-oss", base_url="http://127.0.0.1:11434"):
        self.model = model
        self.base_url = base_url

    def _call(self, prompt: str) -> str:
        payload = {
            "model": self.model,
            "prompt": prompt,
            "stream": False  # Không sử dụng stream trong ví dụ này
        }
        
        # Gửi yêu cầu POST tới Ollama API
        response = requests.post(f"{self.base_url}/api/generate", json=payload)
        
        if response.status_code != 200:
            raise Exception(f"Ollama API error: {response.status_code} {response.text}")
        
        result = response.json()
        return result["text"]  # Đoạn văn bản trả về từ Ollama

# Đọc nội dung từ PDF
def read_pdf(file_path):
    with pdfplumber.open(file_path) as pdf:
        text = ""
        for page in pdf.pages:
            text += page.extract_text()  # Extract text from each page
    return text

# Tạo prompt và sử dụng Ollama GPT-OSS
def summarize_pdf_content(pdf_text):
    ollama_llm = OllamaLLM(model="gpt-oss", base_url="http://127.0.0.1:11434")
    
    # Tạo chuỗi tóm tắt Langchain với Ollama
    template = """Summarize the following text:
    {text}"""
    
    prompt = PromptTemplate(input_variables=["text"], template=template)
    chain = LLMChain(llm=ollama_llm, prompt=prompt)

    # Tóm tắt nội dung PDF
    result = chain.run({"text": pdf_text})
    return result

# Đọc và tóm tắt nội dung PDF
def read_and_summarize_pdf(file_path):
    pdf_text = read_pdf(file_path)
    return summarize_pdf_content(pdf_text)

# Đoạn code thử nghiệm
pdf_file_path = 'path_to_your_pdf.pdf'  # Đảm bảo bạn thay bằng đường dẫn đến file PDF của bạn
summary = read_and_summarize_pdf(pdf_file_path)
print("Tóm tắt nội dung PDF: ", summary)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import requests
# ----> 2 from langchain.llms import BaseLLM
#       4 class OllamaLLM(BaseLLM):
#       5     def __init__(self, model="gpt-oss", base_url="http://127.0.0.1:11434"):
#
# ModuleNotFoundError: No module named 'langchain.llms'

# %%
# !pip install langchain requests pdfplumber
# Out:
# Requirement already satisfied: langchain in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (1.0.5)
# Requirement already satisfied: requests in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (2.32.5)
# Requirement already satisfied: pdfplumber in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (0.11.8)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.4 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.4)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain) (1.0.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain) (2.12.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (0.4.42)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.0.4->langchain) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.4->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.2)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.2.9)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.0)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.0.4->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: pdfminer.six==20251107 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pdfplumber) (20251107)
# Requirement already satisfied: Pillow>=9.1 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pdfplumber) (11.0.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pdfplumber) (5.0.0)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from pdfminer.six==20251107->pdfplumber) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=36.0.0->pdfminer.six==20251107->pdfplumber) (2.23)
# Requirement already satisfied: sniffio>=1.1 in c:\users\cao_ngoc_dung\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
