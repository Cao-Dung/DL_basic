# %%
# pip install langchain
# pip install faiss-cpu # FAISS (để lưu trữ và truy vấn embeddings):
# pip install ollama # Ollama (để sử dụng GPT-OSS từ Ollama):
# pip install PyPDF2 # PyPDF2 (để xử lý PDF nếu bạn cần đọc nội dung từ các file PDF):
# pip install openai  # OpenAI (nếu bạn sử dụng OpenAI để tạo embeddings, trả lời câu hỏi, v.v.):

# %%
# !pip install langchain[extra]
# Out:
# ...
# WARNING: langchain 1.0.5 does not provide the extra 'extra'
